# %% [markdown]
# # Worksheet 11b: Proteomics dataset
# - Case study: https://www.nature.com/articles/srep37871
# ### Malaria data
# - quantify celebral protein expression of 748 proteins in 12 mice (samples) using mass spec experiments
# - 6 mice, two parallel experimental sets (n=12)
# - In each experiment: 2 mice = non-infected controls, 2 mice = day 3 post infection, 2 mice = ECM or experimental celebral malaria (day 8 post infection)
# - protein expression in log2 base format

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
malaria_data = pd.read_csv('malaria.csv', index_col=0)

# %%
malaria_data.shape

# %%
malaria_data.head()

# %%
malaria_data.columns

# %%
malaria_data.dtypes

# %% [markdown]
# ### overall statistics

# %%
malaria_data.describe()
# Out:
#        Sample.1.NI.Sample1  Sample.2.NI.Sample1  Sample.3.d3.pi.Sample1  \
# count           591.000000           591.000000              591.000000
# mean              0.018741            -0.096846               -0.136090
# std               0.352807             0.242460                0.316248
# min              -1.226488            -1.090018               -1.698366
# 25%              -0.182524            -0.249135               -0.344550
# 50%              -0.020263            -0.116964               -0.148311
# 75%               0.154793             0.045542                0.065655
# max               1.687239             0.676707                1.846544
#
#        Sample.4.d3.pi.Sample1  Sample.5.ECM.Sample1  Sample.6.ECM.Sample1  \
# count              591.000000            591.000000            591.000000
# mean                -0.186912              0.257273              0.143834
# std                  0.349886              0.561700              0.484882
# min                 -1.772834             -1.461867             -1.421203
# 25%                 -0.399042             -0.145712             -0.195306
# 50%                 -0.202649              0.255479              0.132509
# 75%                  0.024667              0.606388              0.455201
# max                  0.846193              2.138143              2.338790
#
#        Sample 1\nECM\nSample2  Sample 2\nECM\nSample2  Sample 3\nNI\nSample2  \
# count              636.000000              636.000000             636.000000
# mean                -0.039733                0.433572              -0.141263
# std                  0.387100                0.897728               0.498972
# min                 -1.180796               -3.631490              -2.903402
# 25%                 -0.242904               -0.220424              -0.431201
# 50%                 -0.111954                0.415333              -0.129233
# 75%                  0.065979                1.163893               0.134527
# max                  1.924148                2.752643               2.082204
#
#        Sample 4\nNI\nSample2  Sample 5\nd3 pi\nSample2  \
# count             636.000000                636.000000
# mean               -0.023339                 -0.184807
# std                 0.265459                  0.425344
# min                -0.772762                 -1.576109
# 25%                -0.185618                 -0.459229
# 50%                -0.045670                 -0.211429
# 75%                 0.115044                  0.079249
# max                 1.522205                  1.447687
#
#        Sample 6\nd3 pi\nSample2
# count                636.000000
# mean                  -0.044430
# std                    0.285929
# min                   -0.963776
# 25%                   -0.223822
# 50%                   -0.076210
# 75%                    0.095432
# max                    1.225039

# %% [markdown]
# ### can you get count of null values per sample

# %%
pd.isnull(malaria_data).sum()
# Out:
# Sample.1.NI.Sample1         157
# Sample.2.NI.Sample1         157
# Sample.3.d3.pi.Sample1      157
# Sample.4.d3.pi.Sample1      157
# Sample.5.ECM.Sample1        157
# Sample.6.ECM.Sample1        157
# Sample 1\nECM\nSample2      112
# Sample 2\nECM\nSample2      112
# Sample 3\nNI\nSample2       112
# Sample 4\nNI\nSample2       112
# Sample 5\nd3 pi\nSample2    112
# Sample 6\nd3 pi\nSample2    112
# dtype: int64

# %% [markdown]
# ### plot null values per sample

# %%
fig, ax = plt.subplots(layout='constrained')
ax.scatter(
    pd.isnull(malaria_data).sum().index,
    pd.isnull(malaria_data).sum().values
)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# ### plot raw mean protein expression per sample

# %%
fig, ax1 = plt.subplots(layout='constrained')
ax1.scatter(
    malaria_data.mean().index,
    malaria_data.mean().values
)
ax1.tick_params(axis='x', rotation=90)

# %% [markdown]
# ### plot raw mean protein expression per sample using `df.describe`

# %%
malaria_data.describe()
# Out:
#        Sample.1.NI.Sample1  Sample.2.NI.Sample1  Sample.3.d3.pi.Sample1  \
# count           591.000000           591.000000              591.000000
# mean              0.018741            -0.096846               -0.136090
# std               0.352807             0.242460                0.316248
# min              -1.226488            -1.090018               -1.698366
# 25%              -0.182524            -0.249135               -0.344550
# 50%              -0.020263            -0.116964               -0.148311
# 75%               0.154793             0.045542                0.065655
# max               1.687239             0.676707                1.846544
#
#        Sample.4.d3.pi.Sample1  Sample.5.ECM.Sample1  Sample.6.ECM.Sample1  \
# count              591.000000            591.000000            591.000000
# mean                -0.186912              0.257273              0.143834
# std                  0.349886              0.561700              0.484882
# min                 -1.772834             -1.461867             -1.421203
# 25%                 -0.399042             -0.145712             -0.195306
# 50%                 -0.202649              0.255479              0.132509
# 75%                  0.024667              0.606388              0.455201
# max                  0.846193              2.138143              2.338790
#
#        Sample 1\nECM\nSample2  Sample 2\nECM\nSample2  Sample 3\nNI\nSample2  \
# count              636.000000              636.000000             636.000000
# mean                -0.039733                0.433572              -0.141263
# std                  0.387100                0.897728               0.498972
# min                 -1.180796               -3.631490              -2.903402
# 25%                 -0.242904               -0.220424              -0.431201
# 50%                 -0.111954                0.415333              -0.129233
# 75%                  0.065979                1.163893               0.134527
# max                  1.924148                2.752643               2.082204
#
#        Sample 4\nNI\nSample2  Sample 5\nd3 pi\nSample2  \
# count             636.000000                636.000000
# mean               -0.023339                 -0.184807
# std                 0.265459                  0.425344
# min                -0.772762                 -1.576109
# 25%                -0.185618                 -0.459229
# 50%                -0.045670                 -0.211429
# 75%                 0.115044                  0.079249
# max                 1.522205                  1.447687
#
#        Sample 6\nd3 pi\nSample2
# count                636.000000
# mean                  -0.044430
# std                    0.285929
# min                   -0.963776
# 25%                   -0.223822
# 50%                   -0.076210
# 75%                    0.095432
# max                    1.225039

# %%
malaria_data.describe().loc['mean']
# Out:
# Sample.1.NI.Sample1         0.018741
# Sample.2.NI.Sample1        -0.096846
# Sample.3.d3.pi.Sample1     -0.136090
# Sample.4.d3.pi.Sample1     -0.186912
# Sample.5.ECM.Sample1        0.257273
# Sample.6.ECM.Sample1        0.143834
# Sample 1\nECM\nSample2     -0.039733
# Sample 2\nECM\nSample2      0.433572
# Sample 3\nNI\nSample2      -0.141263
# Sample 4\nNI\nSample2      -0.023339
# Sample 5\nd3 pi\nSample2   -0.184807
# Sample 6\nd3 pi\nSample2   -0.044430
# Name: mean, dtype: float64

# %%
fig, ax = plt.subplots(layout='constrained')
ax.plot(
    malaria_data.describe().loc['mean'].index,
    malaria_data.describe().loc['mean'].values,
    'ro'
)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# # Collaborative Exercises

# %% [markdown]
# ### Exercise 1
# - Plot a boxplot of sample names and raw protein expression

# %%
malaria_data.plot(kind='box')
plt.tick_params(axis='x', rotation=90)
