# %% [markdown]
# # Worksheet2.ipynb
# # Data structures, Data types and manipulations
#    - Strings, lists and tuples
#    - Collaborative exercises

# %% [markdown]
# ## Strings

# %%
gene1 = 'BRCA1'

# %%
gene1
# Out:
# 'BRCA1'

# %% [markdown]
# #### Try double quoted strings

# %%
gene2 = "BRCA1"
gene2
# Out:
# 'BRCA1'

# %% [markdown]
# #### Multiline (para) string

# %%
para = "BRCA1 is a very famous gene.\nSo is TP53."

# %%
para
# Out:
# 'BRCA1 is a very famous gene.\nSo is TP53.'

# %% [markdown]
# #### print function produces a more readable output

# %%
print(para)
# Out:
# BRCA1 is a very famous gene.
# So is TP53.

# %% [markdown]
# #### Triple quoted strings

# %%
para = """
BRCA1 is a very famous gene.
So is TP53.
"""

# %%
para
# Out:
# '\nBRCA1 is a very famous gene.\nSo is TP53.\n'

# %%
print(para)
# Out:
# BRCA1 is a very famous gene.
# So is TP53.

# %% [markdown]
# #### Substring search

# %%
'BRCA1' in para
# Out:
# True

# %%
'BRCA2' in para
# Out:
# False

# %%
'BRCA2' not in para
# Out:
# True

# %% [markdown]
# #### String concatenation

# %%
'BRCA1 is a ' + 'very famous gene'
# Out:
# 'BRCA1 is a very famous gene'

# %% [markdown]
# #### String repetition

# %%
para
# Out:
# '\nBRCA1 is a very famous gene.\nSo is TP53.\n'

# %%
print(para * 3)
# Out:
# BRCA1 is a very famous gene.
# So is TP53.
#
# BRCA1 is a very famous gene.
# So is TP53.
#
# BRCA1 is a very famous gene.
# So is TP53.

# %% [markdown]
# #### String indexing

# %%
gene1
# Out:
# 'BRCA1'

# %% [markdown]
# # The first index or position is always 0 in programming!
# - except in R

# %%
gene1[0]
# Out:
# 'B'

# %%
gene1[1]
# Out:
# 'R'

# %%
gene1[3]
# Out:
# 'A'

# %%
gene1[0], gene1[1], gene1[2], gene1[3], gene1[4]
# Out:
# ('B', 'R', 'C', 'A', '1')

# %% [markdown]
# ### Q: Can you guess the output of `gene1[5]`
# - 1-2 mins

# %%
gene1[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 gene1[5]
#
# IndexError: string index out of range

# %% [markdown]
# #### String in reverse

# %%
gene1[-1], gene1[-2], gene1[-3], gene1[-4], gene1[-5]

# %% [markdown]
# ### Q: What is the output of `gene1[-6]`?
# - 1-2 mins

# %%
gene1[-6]

# %% [markdown]
# #### len function

# %%
len(gene1)

# %% [markdown]
# #### String slicing

# %%
# characters from position 0 (included) to 3 (excluded)
gene1[0:3]

# %%
# characters from position 0 (included) to 3 (excluded)
gene1[:3]

# %%
# characters from position 2 (included) to the end
gene1[2:]

# %%
# slice of gene1 from 0 to 3, through step 2
# 0 (included), 3 (excluded)
gene1[0:3:2]

# %% [markdown]
# #### Slicing a string creates a new string

# %%
gene_slice = gene1[0:3]

# %%
gene_slice

# %% [markdown]
# ### Q: Prove that strings are immutable
# - Try to set position 0 of gene1 to any different base
# - What do you notice?
# - 1-2 mins

# %%
gene1[0] = 'C'
gene1

# %% [markdown]
# ### Some popular string methods
# - https://docs.python.org/3.12/library/stdtypes.html#string-methods

# %% [markdown]
# #### str.find()

# %%
para

# %%
para.find('BRCA1')

# %%
para.find('is')

# %%
# not good behaviour
para.find('BRCA2')

# %% [markdown]
# ### Q: Experiment the same as above with `str.index()`
# - search for `BRCA2`
# - https://docs.python.org/3.12/library/stdtypes.html#string-methods
# - Compare behaviour with `str.find()` What do you see?
# - 1-2 mins

# %%
para.index('BRCA2')

# %% [markdown]
# #### str.format()

# %%
'{} gene length'.format(gene1)

# %%
f'{gene1} gene length'

# %% [markdown]
# #### str.upper(), str.lower()

# %%
gene1.upper(), gene1.lower()

# %%
gene1.isupper(), gene1.islower()

# %% [markdown]
# ### Sequence types
# - list
# - tuple
# - range

# %% [markdown]
# ## Lists: Compound data types

# %% [markdown]
# #### Different ways to construct lists
# - simple assignment
# - list from string
# - list constructor

# %% [markdown]
# #### method 1: simple assignment

# %%
para_list = ['BRCA1', 'is', 'a', 'very', 'famous', 'gene.', 'So', 'is', 'TP53.']

# %%
para_list

# %% [markdown]
# #### method 2: construct list from a string

# %%
para

# %%
para.split()

# %% [markdown]
# ### Q: What is the output of `str.splitlines()`
# - Experiment with the same `str` as above, the one used in `str.split()`
# - https://docs.python.org/3.12/library/stdtypes.html#string-methods
# - explain difference compared to `str.split()`
# - What is in position 0 of `str.splitlines()` and why?
# - 2-3 mins

# %%
para.splitlines()

# %%
####__________(type out answer)___________________

# %% [markdown]
# ### Q: Can you convert `my_fav_gene_string` below into a list
# - 2-3 mins

# %%
my_fav_gene_string = 'BRCA1,BRCA2,TP53'

# %%
my_fav_gene_string.split(",")

# %% [markdown]
# #### method 3: using the list constructor

# %%
# using the list constructor
list(gene1)

# %% [markdown]
# #### List indexing

# %%
para_list

# %% [markdown]
# ### first element of the list is in position 0

# %%
para_list[0]

# %% [markdown]
# #### List slicing
# - slicing a list creates a new list

# %%
para_list_slice = para_list[2:4]

# %%
para_list_slice

# %%
# 2 (included), 6 (excluded), 2 (step size)
para_list_slice2 = para_list[2:6:2]

# %%
para_list_slice2

# %% [markdown]
# #### Lists are mutable, contrary to strings

# %%
para_list[0] = 'BRCA2'

# %%
para_list

# %% [markdown]
# #### List methods
# - https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# ##### append

# %%
para_list.append('and')

# %%
para_list

# %%
para_list.append('KRAS')

# %%
para_list

# %% [markdown]
# ### Q: Can you insert to the start of the list?

# %%
list1 = ['I', 'Think']
list1 + para_list

# %% [markdown]
# ##### sort

# %%
gene_lengths = [400, 600, 500, 300]

# %%
gene_lengths.sort(reverse=True)

# %%
gene_lengths

# %% [markdown]
# ##### sorted

# %%
gene_lengths = [400, 600, 500, 300]
sorted_gene_lengths = sorted(gene_lengths)

# %%
sorted_gene_lengths

# %% [markdown]
# ### Q: Can you convert the list below to a string?
# - hint: use `str.join()`
# - separate by ','

# %%
my_gene_list = ['BRCA1', 'BRCA2', 'TP53']

# %%
",".join(my_gene_list)
# Out:
# 'BRCA1,BRCA2,TP53'

# %% [markdown]
# ## Tuples
# - immutable sequences
# - Ideal for representing heterogenous data you don't want altered

# %%
gene1 = ('BRCA1', 'Chr17', 'Coding')

# %%
gene2 = ('BRCA2', 'Chr13', 'Coding')

# %%
gene1[0]

# %% [markdown]
# ### Q: Test the immutability of tuples
# - Example: Can you change the gene name or chromosome number, or type of gene (`coding`, `non-coding`) in the tuples?
# - What error is raised?
# - 1-2 mins

# %%
gene1[0] = "TP53"

# %% [markdown]
# # Collaborative exercises

# %% [markdown]
# ## Exercise 1
#
# - Make up an amino acid sequence for your favorite gene with your team. Max 15 characters. Look at the codon table for allowed characters if unsure.
# - Store the sequence in a string variable and calculate the length
# - Store the sequence in a list and re-calculate the length
# - Ask one of your team mates to select a position in the sequence and a mutation. Introduce it into the sequence. Print the result. Can you do this in the string ? Why not? how about in the list ?
# - Now ask your friend to introduce mutations in multiple positions e.g. think of this as a strange translocation, positions 4-8 of the protein. Can you introduce this and print the result? Can you do this in the string ? Why, or why not? how about in the list ?

# %%
gene4 = "GAGGTCTCAGTCGCA"
len(gene4)

# %%
split_gene4 = "G,A,G,G,T,C,T,C,A,G,T,C,G,C,A"
s_gene4 = split_gene4.split(",")
len(s_gene4)
s_gene4

# %%
gene4[4] = "C"
gene4

# %%
s_gene4[4] = "C"
s_gene4

# %%
mutations = "CGTCA"
gene4[0:4] + mutations + gene4[8:]

# %%
mutations = ["C","G","T","C","A"]
s_gene4[0:4] + mutations + s_gene4[8:]

# %% [markdown]
# ##### Exercise 1 Responses
# - You can only introduce a mutation to the sequence when it's in a list because strings are immutable.
# - It works for both a string and list, when the method is calling part of the existing sequence on either side of the mutation and replacing that part of the sequence. However, replacing each element using the index would not work.

# %% [markdown]
# ## Exercise 2
#
# - Store the original amino acid sequence you started with in `Exercise 1` in a list
# - Create a copy of this list to store a protein copy
# - Introduce some mutations only in the copy, not in the original protein (gene duplication and divergence model). Decide which positions you want to change in the copy with your colleague
# - Print out the original protein sequence list, and the sequence of the copy

# %%
gene4_list = ["G","A","G","G","T","C","T","C","A","G","T","C","G","C","A"]
c_gene4_list = gene4_list

n_mutations = ["A","T","G","C"]
l_mutations = ["T", "A"]

gene_duplication = c_gene4_list[0:6] + n_mutations + c_gene4_list[10:13] + l_mutations

# %%
orig_prot = "".join(gene4_list)
copy_seq = "".join(gene_duplication)

seq_list = orig_prot + "\n" + copy_seq
print(seq_list)
# Out:
# GAGGTCTCAGTCGCA
# GAGGTCATGCTCGTA

# %% [markdown]
# ## Exercise 3
# - Can you take the `gene1` tuple created in the class and try to make it mutable, i.e replace `BRCA1` with a different gene on `Chr17`?
# - Hint: change the data structure from a tuple to something else

# %%
gene1 = ('BRCA1', 'Chr17', 'Coding')
gene1_list = gene1[0] + "," + gene1[1] + "," + gene1[2]
s_gene1_list = gene1_list.split(",")

# %%
s_gene1_list[0] = "Chr17"
s_gene1_list

# %% [markdown]
# ##### Exercise 3 Response
# - In order to make the tuple mutable, you can store each element of the tuple within a string, then convert the string into a list using the "split" function. From there, reassign the index with the gene that you want.

# %% [markdown]
# ## Exercise 4
# - Create a list of lists, with one list and within in two sublists
# - each sublist should have three gene names in it
# - Decide gene names with your team
# - Can you access the first sublist and the first element of the first sublist?

# %%
list_of_lists = ['Chr17, Chr18, BRCA1', 'Chr19, Chr20, BRCA2']

# %%
list_1 = list_of_lists[0]
list_1

# %%
split_list = list_1.split()
split_list[0]

# %% [markdown]
# ##### Exercise 4 Response
# - Yes! You can access the first sublist using indices, then split that sublist before calling the first element of that list.
