# %%
import numpy as np

# %%
a = 30 - 2 * 5
print(a)
# Out:
# 20

# %%
sentence = 'python is the best'
sentence[0:8:1]
# Out:
# 'python i'

# %%
a = [
[100, 500, 400],
[200, 400, 600]
]
result = a[0][1] + a[1][1]
print(result)
# Out:
# 900

# %%
gene_list3 = ['PTEN', 'PTEN']
gene_list4 = ['KRAS', 'KRAS']
list(set(gene_list3) | set(gene_list4))
# Out:
# ['KRAS', 'PTEN']

# %%
gene_names = ['BCR', 'JAK2', 'ERBB2']
for g in reversed(sorted(gene_names)):
    print(g)
# Out:
# JAK2
# ERBB2
# BCR

# %%
dict_a = {
'gene1': 'chr20',
'gene2': 'chr22',
'gene3': 'chr1'
}
dict_a['gene3'] = 'chr10'
dict_a.values()
# Out:
# dict_values(['chr20', 'chr22', 'chr10'])

# %%
x = np.array([1,2,3,np.nan])
y = ~np.isnan(x)
print(y)
# Out:
# [ True  True  True False]

# %%
x = [i for i in range(5)]
x[:2] = [1,1]
print(x)
# Out:
# [1, 1, 2, 3, 4]

# %%
for num in range(4):
    if num < 2:
        print(f"num:{num}")
        break
    else:
        print(f"num:{num}")
# Out:
# num:0

# %%
i = np.arange(start=0, stop=6, step=2)
i = i + 1
i
# Out:
# array([1, 3, 5])

# %%
a = [1,1,2,3]
b = [4, 2, 1]
set(a) - set(b)
# Out:
# {3}

# %%
a = list(range(6))
a[1:5:2]
# Out:
# [1, 3]
