# %% [markdown]
# # Worksheet8: Pandas DataFrames
# ###### Maryam Abdella

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## DataFrame
# - represents a rectangular table of data and contains a collection of columns, each of which can be a different value type (numeric, string, boolean, etc.)
# - can be thought of as a collection of Series (columns)
# - has both rows and columns, each with their own index
# - different ways to create a DataFrame: from series, from dict, from a file

# %% [markdown]
# ### df from a series
# - pd.DataFrame(series)

# %% [markdown]
# #### simple one column DataFrame
# - construct a simple series 1,2,3,4 from a list
# - pass to pd.DataFrame

# %%
df = pd.DataFrame(
    pd.Series([1,2,3,4])
)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# ### DataFrame has a row index and a column index
# - if you dont specify a row index or column index, it will default to a range index
# ![simple broadcasting](df.png)

# %%
# row index
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# column index
df.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %% [markdown]
# #### specify row index when creating the DataFrame
# - use gene_names BRCA1, BRCA2, SMAD2, TTN as index in the series
# - use values 1,2,3,4
# - pass to pd.DataFrame

# %%
df = pd.DataFrame(
    [1, 2, 3, 4], index=['BRCA1', 'BRCA2', 'SMAD2', 'TTN']
)

# %%
df
# Out:
#        0
# BRCA1  1
# BRCA2  2
# SMAD2  3
# TTN    4

# %%
df.index, df.columns
# Out:
# (Index(['BRCA1', 'BRCA2', 'SMAD2', 'TTN'], dtype='str'),
#  RangeIndex(start=0, stop=1, step=1))

# %% [markdown]
# #### now specify column index when creating the DataFrame
# - name the column `gene_len_kb`

# %%
df = pd.DataFrame(
    [1, 2, 3, 4], index=['BRCA1', 'BRCA2', 'SMAD2', 'TTN']
)
df.columns = ['gene_len_kb']

# %%
df
# Out:
#        gene_len_kb
# BRCA1            1
# BRCA2            2
# SMAD2            3
# TTN              4

# %%
df.index, df.columns
# Out:
# (Index(['BRCA1', 'BRCA2', 'SMAD2', 'TTN'], dtype='str'),
#  Index(['gene_len_kb'], dtype='str'))

# %%
# check the type of data
df.dtypes
# Out:
# gene_len_kb    int64
# dtype: object

# %% [markdown]
# ### df.values

# %%
df.values
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
df.values.shape
# Out:
# (4, 1)

# %%
df.values.ndim
# Out:
# 2

# %%
# guess the output
ser = pd.Series([1, 2, 3], index=["a", "b", "c"])
pd.DataFrame(data=ser, index=["a", "c"])
# Out:
#    0
# a  1
# c  3

# %% [markdown]
# ### df from a dict
# - pd.DataFrame
# - pd.DataFrame.from_dict()

# %% [markdown]
# #### create a dictionary from
# - gene_expression = [2, 4, 4, 5]
# - gene_names = ['BRCA1', 'BRCA2', 'SMAD2', 'TTN']
# - pass it to pd.DataFrame

# %%
gene_expression = [2, 4, 4, 5]
gene_names = ['BRCA1', 'BRCA2', 'SMAD2', 'TTN']

# %%
d = {k:gene_expression[idx] for idx,k in enumerate(gene_names)}

# %%
d
# Out:
# {'BRCA1': 2, 'BRCA2': 4, 'SMAD2': 4, 'TTN': 5}

# %% [markdown]
# #### pd.DataFrame(dict)
# - keys of the dictionary = column labels by default
# - try adding index=['gene_names']

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.DataFrame(d)
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/internals/construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/internals/construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/internals/construction.py:634, in _extract_index(data)
#     631         raise ValueError("Per-column arrays must each be 1-dimensional")
#     633 if not indexes and not raw_lengths:
# --> 634     raise ValueError("If using all scalar values, you must pass an index")
#     636 if have_series:
#     637     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
pd.DataFrame(d, index=['gene_names'])
# Out:
#             BRCA1  BRCA2  SMAD2  TTN
# gene_names      2      4      4    5

# %% [markdown]
# #### now modify the dictionary such that for each gene, there are two values
# - create a new dictionary with gene_expression, gene_expression + 1
# - pass to pd.DataFrame

# %%
d = {k: [gene_expression[idx], gene_expression[idx]+1] for idx,k in enumerate(gene_names)}

# %%
pd.DataFrame(d)
# Out:
#    BRCA1  BRCA2  SMAD2  TTN
# 0      2      4      4    5
# 1      3      5      5    6

# %% [markdown]
# #### can you add row index to the above
# - 'timept.0', 'timept.1'

# %%
pd.DataFrame(d, index=['timept.0', 'timept.1'])
# Out:
#           BRCA1  BRCA2  SMAD2  TTN
# timept.0      2      4      4    5
# timept.1      3      5      5    6

# %% [markdown]
# ### Can you instead make the rows of dataframe = keys of the dictionary
# - use `pd.DataFrame.from_dict`
# - orient='index' orients the keys of the dictionary as row index

# %%
pd.DataFrame.from_dict(d, orient='index')
# Out:
#        0  1
# BRCA1  2  3
# BRCA2  4  5
# SMAD2  4  5
# TTN    5  6

# %% [markdown]
# ### can you change colnames above to 'timept.0', 'timept.1'

# %%
df = pd.DataFrame.from_dict(d, orient='index', columns=['timept.0', 'timept.1'])

# %%
df
# Out:
#        timept.0  timept.1
# BRCA1         2         3
# BRCA2         4         5
# SMAD2         4         5
# TTN           5         6

# %% [markdown]
# ### transpose the df

# %%
df.T
# Out:
#           BRCA1  BRCA2  SMAD2  TTN
# timept.0      2      4      4    5
# timept.1      3      5      5    6

# %% [markdown]
# ### Rename the index and columns
# - using .index and .columns
# - using rename

# %%
df = pd.DataFrame(
    {
        'col1': [2,3],
        'col2': [4,5]
    }
)

# %%
df
# Out:
#    col1  col2
# 0     2     4
# 1     3     5

# %% [markdown]
# #### rename using index and columns

# %%
# use .index and .columns
df.index = ['a','b']

# %%
df
# Out:
#    col1  col2
# a     2     4
# b     3     5

# %% [markdown]
# #### rename using df.rename
# - df.rename(index={},columns={})

# %%
df.rename(index={'row1':'renamed_row1', 'row2': 'renamed_row2'},
         columns={'new_col1': 'renamed_col1', 'new_col2': 'renamed_col2'})
# Out:
#    col1  col2
# a     2     4
# b     3     5

# %% [markdown]
# ### add a new column to the df

# %%
df = pd.DataFrame(d, index=['timept.0', 'timept.1'])

# %%
df
# Out:
#           BRCA1  BRCA2  SMAD2  TTN
# timept.0      2      4      4    5
# timept.1      3      5      5    6

# %%
df['PTEN'] = [8,9]

# %%
df
# Out:
#           BRCA1  BRCA2  SMAD2  TTN  PTEN
# timept.0      2      4      4    5     8
# timept.1      3      5      5    6     9

# %%
df['foo'] = 8

# %%
df.dtypes
# Out:
# BRCA1    int64
# BRCA2    int64
# SMAD2    int64
# TTN      int64
# PTEN     int64
# foo      int64
# dtype: object

# %% [markdown]
# ### change dtype of a specific column

# %%
df = df.astype({'BRCA1': 'float'})

# %%
df
# Out:
#           BRCA1  BRCA2  SMAD2  TTN  PTEN  foo
# timept.0    2.0      4      4    5     8    8
# timept.1    3.0      5      5    6     9    8

# %%
df.dtypes
# Out:
# BRCA1    float64
# BRCA2      int64
# SMAD2      int64
# TTN        int64
# PTEN       int64
# foo        int64
# dtype: object

# %% [markdown]
# ### df.axes
# -  DataFrame has two axes: one for the rows, one for the columns
# - axis=0
# - axis=1

# %%
df
# Out:
#           BRCA1  BRCA2  SMAD2  TTN  PTEN  foo
# timept.0    2.0      4      4    5     8    8
# timept.1    3.0      5      5    6     9    8

# %%
df.axes
# Out:
# [Index(['timept.0', 'timept.1'], dtype='str'),
#  Index(['BRCA1', 'BRCA2', 'SMAD2', 'TTN', 'PTEN', 'foo'], dtype='str')]

# %%
len(df.axes), df.axes[0], df.axes[1]
# Out:
# (2,
#  Index(['timept.0', 'timept.1'], dtype='str'),
#  Index(['BRCA1', 'BRCA2', 'SMAD2', 'TTN', 'PTEN', 'foo'], dtype='str'))

# %%
# sum by columns, collapse rows
df.sum(axis=0)
# Out:
# BRCA1     5.0
# BRCA2     9.0
# SMAD2     9.0
# TTN      11.0
# PTEN     17.0
# foo      16.0
# dtype: float64

# %%
# sum by rows, collapse columns
df.sum(axis=1)
# Out:
# timept.0    31.0
# timept.1    36.0
# dtype: float64

# %%
df['BRCA1'].sum()
# Out:
# np.float64(5.0)

# %%
df.cumsum(axis=0)
# Out:
#           BRCA1  BRCA2  SMAD2  TTN  PTEN  foo
# timept.0    2.0      4      4    5     8    8
# timept.1    5.0      9      9   11    17   16

# %% [markdown]
# ### Q: how many axes does a series have?
# - can you confirm your answer?

# %%
type(df['BRCA1'].axes)
# Out:
# list

# %% [markdown]
# ### df.shape

# %%
df
# Out:
#           BRCA1  BRCA2  SMAD2  TTN  PTEN  foo
# timept.0    2.0      4      4    5     8    8
# timept.1    3.0      5      5    6     9    8

# %%
df.shape
# Out:
# (2, 6)

# %% [markdown]
# ### df.size
# - num_rows * num_cols

# %%
df.size
# Out:
# 12

# %% [markdown]
# ### df.head

# %%
df.head(n=1)
# Out:
#           BRCA1  BRCA2  SMAD2  TTN  PTEN  foo
# timept.0    2.0      4      4    5     8    8

# %% [markdown]
# ### df.empty

# %%
df.empty
# Out:
# False

# %% [markdown]
# ### df.describe

# %%
df.describe()
# Out:
#           BRCA1     BRCA2     SMAD2       TTN      PTEN  foo
# count  2.000000  2.000000  2.000000  2.000000  2.000000  2.0
# mean   2.500000  4.500000  4.500000  5.500000  8.500000  8.0
# std    0.707107  0.707107  0.707107  0.707107  0.707107  0.0
# min    2.000000  4.000000  4.000000  5.000000  8.000000  8.0
# 25%    2.250000  4.250000  4.250000  5.250000  8.250000  8.0
# 50%    2.500000  4.500000  4.500000  5.500000  8.500000  8.0
# 75%    2.750000  4.750000  4.750000  5.750000  8.750000  8.0
# max    3.000000  5.000000  5.000000  6.000000  9.000000  8.0

# %% [markdown]
# ### DataFrame from a CSV
# - Read in a very simple genomics CSV file
# - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
gene_lengths_data = pd.read_csv('simple_geno.txt')

# %%
gene_lengths_data
# Out:
#    gene_lengths_kb gene_name
# 0                2     BRCA1
# 1                4     BRCA2
# 2                4     SMAD2
# 3                5       TTN

# %%
gene_lengths_data.index = ['gene1', 'gene2', 'gene3', 'gene4']

# %%
gene_lengths_data
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2
# gene3                4     SMAD2
# gene4                5       TTN

# %% [markdown]
# ### Accessing elements of a dataframe
# - rows, cols
# - df.loc
# - df.iloc

# %%
df
# Out:
#           BRCA1  BRCA2  SMAD2  TTN  PTEN  foo
# timept.0    2.0      4      4    5     8    8
# timept.1    3.0      5      5    6     9    8

# %%
df['BRCA1']
# Out:
# timept.0    2.0
# timept.1    3.0
# Name: BRCA1, dtype: float64

# %%
df[['BRCA1', 'BRCA2']]
# Out:
#           BRCA1  BRCA2
# timept.0    2.0      4
# timept.1    3.0      5

# %% [markdown]
# ### df.loc

# %%
gene_lengths_data
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2
# gene3                4     SMAD2
# gene4                5       TTN

# %%
gene_lengths_data.loc['gene1']
# Out:
# gene_lengths_kb        2
# gene_name          BRCA1
# Name: gene1, dtype: object

# %%
gene_lengths_data.loc['gene1', 'gene_name']
# Out:
# 'BRCA1'

# %%
gene_lengths_data.loc['gene1':'gene4']
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2
# gene3                4     SMAD2
# gene4                5       TTN

# %%
gene_lengths_data.loc['gene1':,  'gene_lengths_kb':'gene_name']
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2
# gene3                4     SMAD2
# gene4                5       TTN

# %% [markdown]
# #### Q: Will this work: gene_lengths_data.loc[0]?
# - if it won't can you think of a scenario when it will?

# %%
gene_lengths_data.loc[0]
# Out:
# KeyboardInterrupt

# %% [markdown]
# #### Q: access `gene1` and `gene2` rows by label

# %%
gene_lengths_data.loc[['gene1', 'gene2']]
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2

# %% [markdown]
# ### get `gene_lengths_kb` output  for `gene1`

# %%
gene_lengths_data.loc['gene1','gene_lengths_kb']
# Out:
# np.int64(2)

# %%
# guess the output of the following?
gene_lengths_data.loc[:, 'gene_lengths_kb'] == gene_lengths_data['gene_lengths_kb']
# Out:
# gene1    True
# gene2    True
# gene3    True
# gene4    True
# Name: gene_lengths_kb, dtype: bool

# %% [markdown]
# #### Q: get `gene_lengths_kb` output  for `BRCA1`

# %%
gene_lengths_data
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2
# gene3                4     SMAD2
# gene4                5       TTN

# %%
gene_lengths_data['gene_name'] == 'BRCA1'
# Out:
# gene1     True
# gene2    False
# gene3    False
# gene4    False
# Name: gene_name, dtype: bool

# %%
gene_lengths_data[gene_lengths_data['gene_name'] == 'BRCA1']['gene_lengths_kb']
# Out:
# gene1    2
# Name: gene_lengths_kb, dtype: int64

# %% [markdown]
# #### access gene_lengths_kb column

# %%
gene_lengths_data
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2
# gene3                4     SMAD2
# gene4                5       TTN

# %%
gene_lengths_data['gene_lengths_kb']
# Out:
# gene1    2
# gene2    4
# gene3    4
# gene4    5
# Name: gene_lengths_kb, dtype: int64

# %%
gene_lengths_data['gene_lengths_kb'][2:]
# Out:
# gene3    4
# gene4    5
# Name: gene_lengths_kb, dtype: int64

# %%
gene_lengths_data['gene_lengths_kb'][-2:]
# Out:
# gene3    4
# gene4    5
# Name: gene_lengths_kb, dtype: int64

# %% [markdown]
# ### access df column as an attribute

# %%
gene_lengths_data.columns
# Out:
# Index(['gene_lengths_kb', 'gene_name'], dtype='str')

# %%
# access column as an attribute
gene_lengths_data.gene_lengths_kb
# Out:
# gene1    2
# gene2    4
# gene3    4
# gene4    5
# Name: gene_lengths_kb, dtype: int64

# %%
gene_lengths_data.gene_lengths_kb.sum()
# Out:
# np.int64(15)

# %%
sa = pd.Series([1, 2, 3], index=list('abc'))
sa.a
# Out:
# np.int64(1)

# %% [markdown]
# ### df.iloc

# %%
gene_lengths_data
# Out:
#        gene_lengths_kb gene_name
# gene1                2     BRCA1
# gene2                4     BRCA2
# gene3                4     SMAD2
# gene4                5       TTN

# %%
gene_lengths_data.iloc[0]
# Out:
# gene_lengths_kb        2
# gene_name          BRCA1
# Name: gene1, dtype: object

# %%
gene_lengths_data.iloc[0]['gene_lengths_kb']
# Out:
# np.int64(2)

# %%
gene_lengths_data.iloc[3]['gene_lengths_kb']
# Out:
# np.int64(5)

# %%
gene_lengths_data.iloc[0]['gene_name']

# %%
gene_lengths_data.iloc[:3]

# %%
gene_lengths_data.iloc[:, 1:3]

# %%
# guess the output of the following
gene_lengths_data.iloc[:, 1] == gene_lengths_data['gene_name']

# %%
gene_lengths_data['gene_lengths_kb'][::2]

# %%
gene_lengths_data['gene_lengths_kb'][::-1]

# %% [markdown]
# ## other operators
# - df.at[row, col] (label based)
# - df.iat[row, col] (integer based)

# %% [markdown]
# #### df.at

# %%
gene_lengths_data

# %%
gene_lengths_data.at['gene1', 'gene_name']

# %%
gene_lengths_data.loc['gene1', 'gene_name']

# %%
gene_lengths_data.at['gene4', 'gene_name']

# %%
gene_lengths_data.at['gene2', 'gene_lengths_kb']

# %% [markdown]
# #### get gene length of `BRCA1`

# %%
gene_lengths_data

# %%
indexname = gene_lengths_data[gene_lengths_data['gene_name'] == 'BRCA1'].index[0]
gene_lengths_data.at[indexname, 'gene_lengths_kb']

# %% [markdown]
# ### df.iat[integer, integer]
# - this is analogous to .iloc

# %%
gene_lengths_data

# %%
gene_lengths_data.iat[0, 1]

# %%
gene_lengths_data.iat[0, 0]

# %% [markdown]
# ### Q: will this work?

# %%
gene_lengths_data.iat[:3, 0]

# %%
# doesn't work!!

# %% [markdown]
# ### Looping and aggregation

# %% [markdown]
# #### apply and other methods:
# - Data standardization:
# - Scale the data in each numeric column to have a mean of 0 and stddev of 1
# - calculate the mean and stddev for each column
# - subtract the mean and divide the result by the stddev

# %%
df

# %%
(df - df.mean())/df.std()

# %%
df.apply(np.sum)

# %% [markdown]
# ### Other useful functions

# %% [markdown]
# #### filter operations
# - dropna
# - fillna

# %%
df

# %%
filter_result_df = df[
(df > 3) & (df < 9)
]

# %%
filter_result_df

# %%
# drop rows with missing values
filter_result_df.dropna(axis=0)

# %%
# drop columns with missing values
filter_result_df.dropna(axis=1)

# %%
filter_result_df.fillna(value=0,axis=0)

# %%
filter_result_df.fillna(value=0,axis=1)

# %% [markdown]
# ### other pandas functions to review
# - df.iterrows
# - df.itertuples
# - df.duplicated
# - df.mask
# - df.dropduplicates
# - df.nunique
# - df.sort_values
# - https://pandas.pydata.org/docs/reference/frame.html on the left

# %%
df.iterrows()
df.itertuples()

# %% [markdown]
# # Collaborative Exercises

# %% [markdown]
# ### Exercise 1
# - Construct a toy EEG signal dataset and normalize it to scale the data between 0 and 1
# - Your dataset should have 5 simulated signals recorded in microvolts for 5 different electrodes
# ```
# electrode1: [100, 90, 75, 10, 20]
# electrode2: [150, 85, 75, 45, 60]
# ....
# ```
# - You can choose to implement Min-max normalization using
#   `Xnorm = (X - Xmin)/(Xmax - Xmin)`,  where X = df
# - Explain results, and why you would want to normalize the data

# %%
toy_EEG = np.random.randint(0,200,size=(5,5))
toy_EEG_df = pd.DataFrame(
        toy_EEG, index=['electrode1', 'electrode2', 'electrode3', 'electrode4', 'electrode5'],)
toy_EEG_df

# %%
#creating the min and max values to input in equation (makes it easier)
toy_EEG_min = toy_EEG_df.values.min()
toy_EEG_max = toy_EEG_df.values.max()

#equation
toy_EEG_norm = (toy_EEG_df - toy_EEG_min) / (toy_EEG_max - toy_EEG_min)

toy_EEG_norm

# %%
# Results:

# %% [markdown]
# ### Exercise 2
# - Build a toy brain MRI metadata dataset from 10 patients
# - 5 patients are control, 5 have alzheimers diagnosis (n=10 rows)
# - You will create a dictionary for this dataset
# - Introduce duplicate rows and nan values
# - See example structure below:
#
# ```
# subject_id,subject_age,brain_volume_mm3,hippocampus_volume_mm3,diagnosis
# 1,55,2200000,3500,Control
# 2,75,1100000,np.nan,alzheimers
# 3,65,100000,1800,alzheimers
# 4,45,np.nan,3280,Control
# ....
# ```
# - Load this dictionary data in a pandas dataframe
# - drop duplicates (test by row and column), and explain which method you prefer
# - find the nan values and fill them with the mean of the corresponding column
# - add an additional column for APOE4 status which predicts the risk for alzheimers disease (two values: [positive, negative])
# - what is the mean age by diagnosis type?
# - how many distinct values are there for a combination of APOE4 status and diagnosis?

# %%
mri_data = {1:[55,2200000,3570,'alzheimers'],2:[70,14000,np.nan,'control'],3:[82,1110000,3800,'control'],4:[43,np.nan,3200,'alzheimers'],
    5:[44,2324560,np.nan,'control'],6:[67,2510000,3400,'control'],7:[51,1230000,3200,'alzheimers'],8:[86,2001000,3200,'control'],
    9:[55,2200000,3570,'alzheimers'],10:[67,2510000,3400,'alzheimers']}
mri_data

# %%
mri_df = pd.DataFrame.from_dict(
    mri_data, orient='index', columns=['subject_age','brain_volume_mm3','hippocampus_volume_mm3','diagnosis'])
mri_df

# %%
del_dupes_row = mri_df.drop_duplicates()
del_dupes_row

# %%
del_column_dupes = mri_df.drop_duplicates(subset=['subject_age','brain_volume_mm3','hippocampus_volume_mm3','diagnosis'])
del_column_dupes

# %%
# Dropping the rows feels simpler, since it just dropped everything at once. The other checks each column before dropping the row/values

# %%
mri_df.isna()

# %%
mean_vals = mri_df.mean(numeric_only=True)
fill_mri_df = mri_df.fillna(mean_vals)

# %%
fill_mri_df

# %%
mri_df['APOE4 Status'] = ['positive','negative','negative','positive','negative','positive','negative','negative','negative','postive']
mri_df

# %%
alz_mean = mri_df[mri_df['diagnosis'] == 'alzheimers']['subject_age'].mean()
alz_mean

# %%
ctrl_mean = mri_df[mri_df['diagnosis'] == 'control']['subject_age'].mean()
ctrl_mean

# %%
mri_df[['APEOE4 Status', 'diagnosis']].drop_duplicates()
